# %%
#!/bin/bash
# train_broadcast.sh - Run on RunPod

# Clone repo
# !git clone https://github.com/Eran-BA/PoT.git
# %cd PoT
# Out:
# Cloning into 'PoT'...
# remote: Enumerating objects: 3437, done.
# remote: Counting objects: 100% (326/326), done.
# remote: Compressing objects: 100% (218/218), done.
# remote: Total 3437 (delta 201), reused 222 (delta 102), pack-reused 3111 (from 1)
# Receiving objects: 100% (3437/3437), 2.77 MiB | 19.40 MiB/s, done.
# Resolving deltas: 100% (2281/2281), done.
# /content/PoT

# %%
# Install dependencies
# !pip install torch torchvision torchaudio
# !pip install tqdm numpy huggingface_hub wandb

# %%
# !pip install -U typing_extensions
# Or specifically:
# pip install typing_extensions>=4.7.1

# %%
# Login to Weights & Biases
import wandb
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Find your API key here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# True

# %%
# !python experiments/sudoku_poh_benchmark.py \
    --d-model 512 \
    --d-ff 2048 \
    --model hybrid \
    --controller transformer \
    --d-ctrl 256 \
    --max-depth 32 \
    --injection-mode broadcast \
    --epochs 1500 \
    --batch-size 768 \
    --lr 3e-4 \
    --warmup-steps 2000 \
    --d-model 512 \
    --n-heads 8 \
    --H-cycles 2 \
    --L-cycles 6 \
    --H-layers 2 \
    --L-layers 2 \
    --hrm-grad-style \
    --halt-max-steps 2 \
    --eval-interval 25 \
    --dropout 0.039 \
    --wandb \
    --project feature-injection-ablation \
    --run-name broadcast-transformer-1500ep \
    --download
# Out:
# ...
# Device: cuda
# GPU: NVIDIA A100-SXM4-40GB
# ...
# Note: Augmentation is now ON-THE-FLY (not pre-computed)
# train.csv: 100% 719M/719M [00:01<00:00, 416MB/s]
#   Train puzzles: 9000, Val puzzles: 1000
# Processing train: 100% 9000/9000 [00:00<00:00, 34852.98it/s]
#   train: 9000 puzzles (augmentation: on-the-fly)
# Processing val: 100% 1000/1000 [00:00<00:00, 34573.09it/s]
#   val: 1000 puzzles (augmentation: on-the-fly)
# test.csv: 100% 79.4M/79.4M [00:01<00:00, 63.9MB/s]
# Processing test: 422786it [00:12, 33119.79it/s]
#   test: 422786 puzzles
# ✓ Dataset saved to data/sudoku-extreme-10k-aug-100
# [train] Loaded 9000 puzzles
#   Augmentation: ON-THE-FLY
# [val] Loaded 1000 puzzles
#   Augmentation: OFF
# Using VAL split (held-out training puzzles) for evaluation
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# ...

# %%
# !python experiments/sudoku_poh_benchmark.py \
    --d-model 512 \
    --d-ff 2048 \
    --model hybrid \
    --controller transformer \
    --d-ctrl 256 \
    --max-depth 32 \
    --injection-mode broadcast \
    --epochs 3000 \
    --batch-size 768 \
    --lr 3e-4 \
    --warmup-steps 2000 \
    --n-heads 8 \
    --H-cycles 2 \
    --L-cycles 6 \
    --H-layers 2 \
    --L-layers 2 \
    --hrm-grad-style \
    --halt-max-steps 3 \
    --eval-interval 25 \
    --dropout 0.039 \
    --wandb \
    --project feature-injection-ablation \
    --run-name broadcast-phase2-halt3 \
    --resume "eranbt92-open-university-of-israel/feature-injection-ablation/hybrid-transformer-best:latest" \
    --download
# Out:
# ...
# Device: cuda
# GPU: NVIDIA A100-SXM4-40GB
# ...
# Note: Augmentation is now ON-THE-FLY (not pre-computed)
# train.csv: 100% 719M/719M [00:01<00:00, 589MB/s]
#   Train puzzles: 9000, Val puzzles: 1000
# Processing train: 100% 9000/9000 [00:00<00:00, 34534.22it/s]
#   train: 9000 puzzles (augmentation: on-the-fly)
# Processing val: 100% 1000/1000 [00:00<00:00, 35208.38it/s]
#   val: 1000 puzzles (augmentation: on-the-fly)
# test.csv: 100% 79.4M/79.4M [00:01<00:00, 63.3MB/s]
# Processing test: 422786it [00:12, 33245.25it/s]
#   test: 422786 puzzles
# ✓ Dataset saved to data/sudoku-extreme-10k-aug-100
# [train] Loaded 9000 puzzles
#   Augmentation: ON-THE-FLY
# [val] Loaded 1000 puzzles
#   Augmentation: OFF
# Using VAL split (held-out training puzzles) for evaluation
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# ...

# %%
# !python experiments/sudoku_poh_benchmark.py \
    --d-model 512 \
    --d-ff 2048 \
    --model hybrid \
    --controller transformer \
    --d-ctrl 256 \
    --max-depth 32 \
    --injection-mode broadcast \
    --epochs 3000 \
    --batch-size 768 \
    --lr 3e-4 \
    --warmup-steps 2000 \
    --n-heads 8 \
    --H-cycles 2 \
    --L-cycles 6 \
    --H-layers 2 \
    --L-layers 2 \
    --hrm-grad-style \
    --halt-max-steps 4 \
    --eval-interval 25 \
    --dropout 0.039 \
    --wandb \
    --project feature-injection-ablation \
    --run-name broadcast-phase2-halt4 \
    --resume "eranbt92-open-university-of-israel/feature-injection-ablation/hybrid-transformer-best:latest" \
    --download
# Out:
# ...
# Device: cuda
# GPU: NVIDIA A100-SXM4-40GB
# ...
# Note: Augmentation is now ON-THE-FLY (not pre-computed)
# train.csv: 100% 719M/719M [00:01<00:00, 585MB/s]
#   Train puzzles: 9000, Val puzzles: 1000
# Processing train: 100% 9000/9000 [00:00<00:00, 34976.21it/s]
#   train: 9000 puzzles (augmentation: on-the-fly)
# Processing val: 100% 1000/1000 [00:00<00:00, 34818.19it/s]
#   val: 1000 puzzles (augmentation: on-the-fly)
# test.csv: 100% 79.4M/79.4M [00:01<00:00, 68.3MB/s]
# Processing test: 422786it [00:12, 33288.91it/s]
#   test: 422786 puzzles
# ✓ Dataset saved to data/sudoku-extreme-10k-aug-100
# [train] Loaded 9000 puzzles
#   Augmentation: ON-THE-FLY
# [val] Loaded 1000 puzzles
#   Augmentation: OFF
# Using VAL split (held-out training puzzles) for evaluation
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# ...

# %%
# !python experiments/sudoku_poh_benchmark.py \
    --d-model 512 \
    --d-ff 2048 \
    --model hybrid \
    --controller transformer \
    --d-ctrl 256 \
    --max-depth 32 \
    --injection-mode broadcast \
    --epochs 3000 \
    --batch-size 768 \
    --lr 3e-4 \
    --warmup-steps 2000 \
    --n-heads 8 \
    --H-cycles 2 \
    --L-cycles 6 \
    --H-layers 2 \
    --L-layers 2 \
    --hrm-grad-style \
    --halt-max-steps 6 \
    --eval-interval 25 \
    --dropout 0.039 \
    --wandb \
    --project feature-injection-ablation \
    --run-name broadcast-phase2-halt6 \
    --resume "eranbt92-open-university-of-israel/feature-injection-ablation/hybrid-transformer-best:latest" \
    --download
# Out:
# ...
# Device: cuda
# GPU: NVIDIA A100-SXM4-40GB
# ...
# Note: Augmentation is now ON-THE-FLY (not pre-computed)
#   Train puzzles: 9000, Val puzzles: 1000
# Processing train: 100% 9000/9000 [00:00<00:00, 35006.44it/s]
#   train: 9000 puzzles (augmentation: on-the-fly)
# Processing val: 100% 1000/1000 [00:00<00:00, 35006.21it/s]
#   val: 1000 puzzles (augmentation: on-the-fly)
# Processing test: 422786it [00:12, 32871.71it/s]
#   test: 422786 puzzles
# ✓ Dataset saved to data/sudoku-extreme-10k-aug-100
# [train] Loaded 9000 puzzles
#   Augmentation: ON-THE-FLY
# [val] Loaded 1000 puzzles
#   Augmentation: OFF
# Using VAL split (held-out training puzzles) for evaluation
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# Hybrid model: H_cycles=2, L_cycles=6
# H_layers=2, L_layers=2, dropout=0.039
# Controller: transformer
# ...

# %%
# !python experiments/sudoku_poh_benchmark.py \
    --d-model 512 \
    --d-ff 2048 \
    --model hybrid \
    --controller transformer \
    --d-ctrl 256 \
    --max-depth 32 \
    --injection-mode broadcast \
    --epochs 4500 \
    --batch-size 768 \
    --lr 3e-4 \
    --warmup-steps 2000 \
    --n-heads 8 \
    --H-cycles 4 \
    --L-cycles 12 \
    --H-layers 2 \
    --L-layers 2 \
    --hrm-grad-style \
    --halt-max-steps 8 \
    --eval-interval 25 \
    --dropout 0.039 \
    --wandb \
    --project feature-injection-ablation \
    --run-name broadcast-phase2-halt8 \
    --resume "eranbt92-open-university-of-israel/feature-injection-ablation/hybrid-transformer-best:latest" \
    --download
# Out:
# ...
# Device: cuda
# GPU: NVIDIA A100-SXM4-80GB
# ...
# Note: Augmentation is now ON-THE-FLY (not pre-computed)
# train.csv: 100% 719M/719M [00:05<00:00, 134MB/s]
#   Train puzzles: 9000, Val puzzles: 1000
# Processing train: 100% 9000/9000 [00:00<00:00, 34998.16it/s]
#   train: 9000 puzzles (augmentation: on-the-fly)
# Processing val: 100% 1000/1000 [00:00<00:00, 34676.85it/s]
#   val: 1000 puzzles (augmentation: on-the-fly)
# test.csv: 100% 79.4M/79.4M [00:02<00:00, 30.6MB/s]
# Processing test: 422786it [00:12, 33376.57it/s]
#   test: 422786 puzzles
# ✓ Dataset saved to data/sudoku-extreme-10k-aug-100
# [train] Loaded 9000 puzzles
#   Augmentation: ON-THE-FLY
# [val] Loaded 1000 puzzles
#   Augmentation: OFF
# Using VAL split (held-out training puzzles) for evaluation
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# ...
